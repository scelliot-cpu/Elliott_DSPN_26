# %% [markdown]
# <a href="https://colab.research.google.com/github/scelliot-cpu/Elliott_DSPN_26/blob/master/Elliott_DSPN_S26_FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How Age and Reaction Time Influence Sensorimotor Adaptation

# %% [markdown]
# ##Background
# Sensorimotor adaptation is the process by which individuals adjust their movements in response to altered sensory feedback. In this dataset, participants completed a visuomotor rotation task where the cursor was rotated relative to hand movement.
#
# This project investigates how individual differences in age and reaction time relate to motor adaptation. Understanding these relationships can provide insight into how learning and motor control change across development.

# %% [markdown]
# ##Hypotheses
# H1: Children will show reduced early motor adaptation relative to young adults.
#
# H2: Children will show reduced late motor adaptation relative to young adults.
#
# H3: Children will show smaller aftereffects than young adults.
#
# H4: Children will have a slower reaction time than young adults.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data <- read.csv("/content/drive/MyDrive/DSPN_Project/testmybrain_clean_onetar_2March2023 - testmybrain_clean_onetar_2March2023.csv")

head(data)
# Out:
#   TN Subject.ID                           ST   RT  MT  ti ri
# 1 1  02a12b38-eabd-4291-b58a-ca6fa0910470 2164 736 256 0  0
# 2 2  02a12b38-eabd-4291-b58a-ca6fa0910470  907 366 663 0  0
# 3 3  02a12b38-eabd-4291-b58a-ca6fa0910470 1101 298 308 0  0
# 4 4  02a12b38-eabd-4291-b58a-ca6fa0910470  992 294  39 0  0
# 5 5  02a12b38-eabd-4291-b58a-ca6fa0910470 2400 165 184 0  0
# 6 6  02a12b38-eabd-4291-b58a-ca6fa0910470 1469  96 217 0  0
#   Group                                        CCW   numtar ⋯ screenheight
# 1 /static/js/cw45tar0_tgtfile_5Dec2020_V1.json FALSE 1      ⋯ 722
# 2 /static/js/cw45tar0_tgtfile_5Dec2020_V1.json FALSE 1      ⋯ 722
# 3 /static/js/cw45tar0_tgtfile_5Dec2020_V1.json FALSE 1      ⋯ 722
# 4 /static/js/cw45tar0_tgtfile_5Dec2020_V1.json FALSE 1      ⋯ 722
# 5 /static/js/cw45tar0_tgtfile_5Dec2020_V1.json FALSE 1      ⋯ 722
# 6 /static/js/cw45tar0_tgtfile_5Dec2020_V1.json FALSE 1      ⋯ 722
#   screenwidth endtime               clumsy   seedisplay videogames major
# 1 1536        3/29/2021 10:8.47.986 Disagree yes        Agree      Psychology
# 2 1536        3/29/2021 10:8.47.986 Disagree yes        Agree      Psychology
# 3 1536        3/29/2021 10:8.47.986 Disagree yes        Agree      Psychology
# 4 1536        3/29/2021 10:8.47.986 Disagree yes        Agree      Psychology
# 5 1536        3/29/2021 10:8.47.986 Disagree yes        Agree      Psychology
# 6 1536        3/29/2021 10:8.47.986 Disagree yes        Agree      Psychology
#   Sleep ComputerUsage gameIndex
# 1 6     9             easy
# 2 6     9             easy
# 3 6     9             easy
# 4 6     9             easy
# 5 6     9             easy
# 6 6     9             easy
